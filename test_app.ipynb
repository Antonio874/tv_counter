# %%
import os
import sys

print("Проверка установленных пакетов...")
try:
    import flask
    print("✓ Flask установлен")
except ImportError:
    print("✗ Flask НЕ установлен")
    sys.exit(1)

try:
    import cv2
    print("✓ OpenCV установлен")
except ImportError:
    print("✗ OpenCV НЕ установлен")

try:
    from ultralytics import YOLO
    print("✓ Ultralytics (YOLO) установлен")
except ImportError:
    print("✗ Ultralytics НЕ установлен")

print("\nСоздание структуры папок...")
os.makedirs('uploads', exist_ok=True)
os.makedirs('static/results', exist_ok=True)
os.makedirs('templates', exist_ok=True)

print("✓ Папки созданы")
print("\nГотово! Теперь запустите:")
print("python app.py")
# Out:
# Проверка установленных пакетов...
# ✓ Flask установлен
# ✓ OpenCV установлен
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\novan\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✓ Ultralytics (YOLO) установлен
#
# Создание структуры папок...
# ✓ Папки созданы
#
# Готово! Теперь запустите:
# python app.py
